# %%
import sys
import os
# !{sys.executable} -m pip install pdfplumber
# !{sys.executable} -m pip install PyPDF2
# !{sys.executable} -m pip install pymupdf
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install Path
# Out:
# Requirement already satisfied: pdfplumber in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (0.11.9)
# Requirement already satisfied: pdfminer.six==20251230 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in /opt/homebrew/lib/python3.14/site-packages (from pdfplumber) (12.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from pdfplumber) (5.5.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from pdfminer.six==20251230->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)
# Requirement already satisfied: PyPDF2 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: pymupdf in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (1.27.1)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in /opt/homebrew/lib/python3.14/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.10/libexec/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.14/site-packages (2.3.4)

# %%
from PyPDF2 import PdfReader
from pathlib import Path

# %%
def extract_text(path):
    return ''.join([page.extract_text() or "" for page in PdfReader(path).pages])
def get_filenames(path):
    return [item.name for item in Path(path).iterdir() if item.is_file()]
def get_pdfs(path):
    return {item.name : extract_text(path + item.name) for item in Path(path).iterdir() if item.is_file()}
